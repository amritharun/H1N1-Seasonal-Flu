# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("data/H1N1_Flu_Vaccines.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26707 entries, 0 to 26706
# Data columns (total 38 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   respondent_id                26707 non-null  int64
#  1   h1n1_concern                 26707 non-null  float64
#  2   h1n1_knowledge               26707 non-null  float64
#  3   behavioral_antiviral_meds    26707 non-null  float64
#  4   behavioral_avoidance         26707 non-null  float64
#  5   behavioral_face_mask         26707 non-null  float64
#  6   behavioral_wash_hands        26707 non-null  float64
#  7   behavioral_large_gatherings  26707 non-null  float64
#  8   behavioral_outside_home      26707 non-null  float64
#  9   behavioral_touch_face        26707 non-null  float64
#  10  doctor_recc_h1n1             26707 non-null  float64
#  11  doctor_recc_seasonal         26707 non-null  float64
#  12  chronic_med_condition        26707 non-null  float64
#  13  child_under_6_months         26707 non-null  float64
#  14  health_worker                26707 non-null  float64
#  15  health_insurance             26707 non-null  float64
#  16  opinion_h1n1_vacc_effective  26316 non-null  float64
#  17  opinion_h1n1_risk            26319 non-null  float64
#  18  opinion_h1n1_sick_from_vacc  26312 non-null  float64
#  19  opinion_seas_vacc_effective  26245 non-null  float64
#  20  opinion_seas_risk            26193 non-null  float64
#  21  opinion_seas_sick_from_vacc  26170 non-null  float64
#  22  age_group                    26707 non-null  object
#  23  education                    25300 non-null  object
#  24  race                         26707 non-null  object
#  25  sex                          26707 non-null  object
#  26  income_poverty               22284 non-null  object
#  27  marital_status               25299 non-null  object
#  28  rent_or_own                  24665 non-null  object
#  29  employment_status            25244 non-null  object
#  30  hhs_geo_region               26707 non-null  object
#  31  census_msa                   26707 non-null  object
#  32  household_adults             26458 non-null  float64
#  33  household_children           26458 non-null  float64
#  34  employment_industry          13377 non-null  object
#  35  employment_occupation        13237 non-null  object
#  36  h1n1_vaccine                 26707 non-null  int64
#  37  seasonal_vaccine             26707 non-null  int64
# dtypes: float64(23), int64(3), object(12)
# memory usage: 7.7+ MB

# %%
df = df.set_index('respondent_id')
df.columns
# Out:
# Index(['h1n1_concern', 'h1n1_knowledge', 'behavioral_antiviral_meds',
#        'behavioral_avoidance', 'behavioral_face_mask', 'behavioral_wash_hands',
#        'behavioral_large_gatherings', 'behavioral_outside_home',
#        'behavioral_touch_face', 'doctor_recc_h1n1', 'doctor_recc_seasonal',
#        'chronic_med_condition', 'child_under_6_months', 'health_worker',
#        'health_insurance', 'opinion_h1n1_vacc_effective', 'opinion_h1n1_risk',
#        'opinion_h1n1_sick_from_vacc', 'opinion_seas_vacc_effective',
#        'opinion_seas_risk', 'opinion_seas_sick_from_vacc', 'age_group',
#        'education', 'race', 'sex', 'income_poverty', 'marital_status',
#        'rent_or_own', 'employment_status', 'hhs_geo_region', 'census_msa',
#        'household_adults', 'household_children', 'employment_industry',
#        'employment_occupation', 'h1n1_vaccine', 'seasonal_vaccine'],
#       dtype='object')

# %%
df['h1n1_concern'].fillna(value=df['h1n1_concern'].mean(), inplace=True)
df['h1n1_knowledge'].fillna(value=df['h1n1_concern'].mean(), inplace=True)
df['household_adults'].fillna(value=df['household_adults'].mean(), inplace=True)
df['household_children'].fillna(value=df['household_children'].mean(), inplace=True)
df['income_poverty'].fillna(value=df['income_poverty'].value_counts().max(), inplace=True)

# %%
from sklearn.impute import KNNImputer
imputer = KNNImputer(n_neighbors=10)
df[binary+opinion] = imputer.fit_transform(df[binary+opinion])

# %%
df['marital_status'] = df['marital_status'].map(lambda x: True if (x == 'Married') False if (x == 'Not Married'))
# Out:
#   File "<ipython-input-160-d4dfbf287516>", line 1
#     df['marital_status'] = df['marital_status'].map(lambda x: True if (x == 'Married') False if (x == 'Not Married'))
#                                                                                            ^
# SyntaxError: invalid syntax

# %%
df[binary+opinion]
# Out:
#       behavioral_antiviral_meds behavioral_avoidance behavioral_face_mask  \
# 0                         False                False                False
# 1                         False                 True                False
# 2                         False                 True                False
# 3                         False                 True                False
# 4                         False                 True                False
# ...                         ...                  ...                  ...
# 26702                     False                 True                False
# 26703                     False                 True                False
# 26704                     False                 True                 True
# 26705                     False                False                False
# 26706                     False                 True                False
#
#       behavioral_wash_hands behavioral_large_gatherings  \
# 0                     False                       False
# 1                      True                       False
# 2                     False                       False
# 3                      True                        True
# 4                      True                        True
# ...                     ...                         ...
# 26702                 False                       False
# 26703                  True                       False
# 26704                  True                        True
# 26705                 False                       False
# 26706                 False                       False
#
#       behavioral_outside_home behavioral_touch_face doctor_recc_h1n1  \
# 0                        True                  True            False
# 1                        True                  True            False
# 2                       False                 False            False
# 3                       False                 False            False
# 4                       False                  True            False
# ...                       ...                   ...              ...
# 26702                    True                 False            False
# 26703                   False                 False             True
# 26704                   False                  True            False
# 26705                   False                 False            False
# 26706                   False                 False            False
#
#       doctor_recc_seasonal chronic_med_condition child_under_6_months  \
# 0                    False                 False                False
# 1                    False                 False                False
# 2                    False                  True                False
# 3                     True                  True                False
# 4                    False                 False                False
# ...                    ...                   ...                  ...
# 26702                False                 False                False
# 26703                 True                 False                False
# 26704                False                 False                False
# 26705                False                 False                False
# 26706                False                 False                False
#
#       health_worker health_insurance marital_status  \
# 0             False             True          False
# 1             False             True          False
# 2             False            False          False
# 3             False            False          False
# 4             False            False           True
# ...             ...              ...            ...
# 26702         False            False          False
# 26703          True             True          False
# 26704         False            False          False
# 26705         False            False           True
# 26706         False             True           True
#
#        opinion_h1n1_vacc_effective  opinion_h1n1_risk  \
# 0                              3.0                1.0
# 1                              5.0                4.0
# 2                              3.0                1.0
# 3                              3.0                3.0
# 4                              3.0                3.0
# ...                            ...                ...
# 26702                          3.0                1.0
# 26703                          4.0                2.0
# 26704                          4.0                4.0
# 26705                          3.0                1.0
# 26706                          5.0                1.0
#
#        opinion_h1n1_sick_from_vacc  opinion_seas_vacc_effective  \
# 0                              2.0                          2.0
# 1                              4.0                          4.0
# 2                              1.0                          4.0
# 3                              5.0                          5.0
# 4                              2.0                          3.0
# ...                            ...                          ...
# 26702                          1.0                          5.0
# 26703                          2.0                          5.0
# 26704                          2.0                          5.0
# 26705                          2.0                          2.0
# 26706                          1.0                          5.0
#
#        opinion_seas_risk  opinion_seas_sick_from_vacc
# 0                    1.0                          2.0
# 1                    2.0                          4.0
# 2                    1.0                          2.0
# 3                    4.0                          1.0
# 4                    1.0                          4.0
# ...                  ...                          ...
# 26702                2.0                          2.0
# 26703                1.0                          1.0
# 26704                4.0                          2.0
# 26705                1.0                          2.0
# 26706                1.0                          1.0
#
# [26707 rows x 20 columns]

# %%
df['rent_or_own'].value_counts()
# Out:
# Own     18736
# Rent     5929
# Name: rent_or_own, dtype: int64

# %%
df['employment_status'].value_counts()
df = pd.get_dummies(df, columns=['employment_status'])

# %%
df.head()
# Out:
#    respondent_id  h1n1_concern  h1n1_knowledge behavioral_antiviral_meds  \
# 0              0           1.0             0.0                     False
# 1              1           3.0             2.0                     False
# 2              2           1.0             1.0                     False
# 3              3           1.0             1.0                     False
# 4              4           2.0             1.0                     False
#
#   behavioral_avoidance behavioral_face_mask behavioral_wash_hands  \
# 0                False                False                 False
# 1                 True                False                  True
# 2                 True                False                 False
# 3                 True                False                  True
# 4                 True                False                  True
#
#   behavioral_large_gatherings behavioral_outside_home behavioral_touch_face  \
# 0                       False                    True                  True
# 1                       False                    True                  True
# 2                       False                   False                 False
# 3                        True                   False                 False
# 4                        True                   False                  True
#
#    ... rent_or_own   employment_status hhs_geo_region  \
# 0  ...         Own  Not in Labor Force       oxchjgsf
# 1  ...        Rent            Employed       bhuqouqj
# 2  ...         Own            Employed       qufhixun
# 3  ...        Rent  Not in Labor Force       lrircsnp
# 4  ...         Own            Employed       qufhixun
#
#                  census_msa household_adults household_children  \
# 0                   Non-MSA              0.0                0.0
# 1  MSA, Not Principle  City              0.0                0.0
# 2  MSA, Not Principle  City              2.0                0.0
# 3       MSA, Principle City              0.0                0.0
# 4  MSA, Not Principle  City              1.0                0.0
#
#    employment_industry  employment_occupation  h1n1_vaccine  seasonal_vaccine
# 0                  NaN                    NaN         False                 0
# 1             pxcmvdjn               xgwztkwe         False                 1
# 2             rucpziij               xtkaffoo         False                 0
# 3                  NaN                    NaN         False                 1
# 4             wxleyezf               emcorrxb         False                 0
#
# [5 rows x 38 columns]

# %%
df[opinion]
# Out:
#        opinion_h1n1_vacc_effective  opinion_h1n1_risk  \
# 0                              3.0                1.0
# 1                              5.0                4.0
# 2                              3.0                1.0
# 3                              3.0                3.0
# 4                              3.0                3.0
# ...                            ...                ...
# 26702                          3.0                1.0
# 26703                          4.0                2.0
# 26704                          4.0                4.0
# 26705                          3.0                1.0
# 26706                          5.0                1.0
#
#        opinion_h1n1_sick_from_vacc  opinion_seas_vacc_effective  \
# 0                              2.0                          2.0
# 1                              4.0                          4.0
# 2                              1.0                          4.0
# 3                              5.0                          5.0
# 4                              2.0                          3.0
# ...                            ...                          ...
# 26702                          1.0                          5.0
# 26703                          2.0                          5.0
# 26704                          2.0                          5.0
# 26705                          2.0                          2.0
# 26706                          1.0                          5.0
#
#        opinion_seas_risk  opinion_seas_sick_from_vacc
# 0                    1.0                          2.0
# 1                    2.0                          4.0
# 2                    1.0                          2.0
# 3                    4.0                          1.0
# 4                    1.0                          4.0
# ...                  ...                          ...
# 26702                2.0                          2.0
# 26703                1.0                          1.0
# 26704                4.0                          2.0
# 26705                1.0                          2.0
# 26706                1.0                          1.0
#
# [26707 rows x 6 columns]

# %%
df['household_children'].value_counts()
# Out:
# 0.0    4133
# 1.0     960
# 2.0     858
# 3.0     486
# Name: household_children, dtype: int64

# %%
categorical = ['age_group','education','race', 'sex',
               'income_poverty', 'marital_status',
               'rent_or_own','employment_status',
               'hhs_geo_region','census_msa','employment_industry',
              'employment_occupation']
for category in categorical:
    df[category] = df[category].astype("category")
df['household_adults'] = df['household_adults'].astype('int8')
df['household_children'] = df['household_children'].astype('int8')

# %%
opinion = ['opinion_h1n1_vacc_effective','opinion_h1n1_risk',
           'opinion_h1n1_sick_from_vacc','opinion_seas_vacc_effective',
           'opinion_seas_risk','opinion_seas_sick_from_vacc']
for col in opinion:
    df[col] = df[col].astype('int8')
    df[col] = df[col].astype("category")

# %%
df['child_under_6_months'].value_counts()
# Out:
# 0.0    23749
# 1.0     2138
# Name: child_under_6_months, dtype: int64

# %%
binary = ['behavioral_antiviral_meds','behavioral_avoidance',
              'behavioral_face_mask', 'behavioral_wash_hands',
              'behavioral_large_gatherings','behavioral_outside_home',
              'behavioral_touch_face', 'doctor_recc_h1n1',
              'doctor_recc_seasonal', 'chronic_med_condition',
              'child_under_6_months', 'health_worker', 
              'health_insurance', 'marital_status']

for col in binary:
    df[col] = df[col].map(lambda x: True if (x == 1.0) else False)
    df[col] = df[col].astype("category")

# %%
df['h1n1_vaccine'] = df['h1n1_vaccine'].map(lambda x: True if (x == 1.0) else False)
df['h1n1_vaccine'] = df['h1n1_vaccine'].astype("category")
df['seasonal_vaccine'] = df['seasonal_vaccine'].map(lambda x: True if (x == 1.0) else False)
df['seasonal_vaccine'] = df['seasonal_vaccine'].astype("category")

# %%
df['behavioral_antiviral_meds'] = df['behavioral_antiviral_meds'].map(lambda x: True if (x == 1.0) else False)
df['behavioral_antiviral_meds'] = df['behavioral_antiviral_meds'].astype("category")

# %%
df['behavioral_avoidance'].value_counts()
# Out:
# True     19228
# False     7479
# Name: behavioral_avoidance, dtype: int64

# %%
def map_marital_status(num):
    if num == 'Married':
        return 1 
    elif num == 'Not Married':
        return 0
    else:
        return num
    
df['marital_status'] = df['marital_status'].map(lambda x:map_marital_status(x))

# %%
df['marital_status'].isna().sum()
# Out:
# 1408

# %%
df['h1n1_concern'] = df['h1n1_concern'].astype("category")

# %%
temp
# Out:
# respondent_id
# 0           Low
# 1          High
# 2           Low
# 3           Low
# 4        Medium
#           ...
# 26702    Medium
# 26703       Low
# 26704    Medium
# 26705       Low
# 26706      None
# Name: h1n1_concern, Length: 26707, dtype: category
# Categories (4, object): ['High', 'Low', 'Medium', 'None']

# %%
def map_h1n1_knowledge(num):
    if num == 2.0:
        return 'High'
    elif num == 1.0:
        return 'Low'
    else:
        return 'None'
df['h1n1_knowledge'] = df['h1n1_knowledge'].map(lambda x:map_h1n1_knowledge(x))
df['h1n1_knowledge'].value_counts()
# Out:
# Low     14598
# High     9487
# None     2622
# Name: h1n1_knowledge, dtype: int64

# %%
df['h1n1_knowledge'].hist()
# Out:
# <AxesSubplot:>

# %%
data = pd.read_pickle('data/data.pkl')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26707 entries, 0 to 26706
# Data columns (total 38 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   h1n1_concern                          26707 non-null  category
#  1   h1n1_knowledge                        26707 non-null  category
#  2   behavioral_antiviral_meds             26707 non-null  category
#  3   behavioral_avoidance                  26707 non-null  category
#  4   behavioral_face_mask                  26707 non-null  category
#  5   behavioral_wash_hands                 26707 non-null  category
#  6   behavioral_large_gatherings           26707 non-null  category
#  7   behavioral_outside_home               26707 non-null  category
#  8   behavioral_touch_face                 26707 non-null  category
#  9   doctor_recc_h1n1                      26707 non-null  category
#  10  doctor_recc_seasonal                  26707 non-null  category
#  11  chronic_med_condition                 26707 non-null  category
#  12  child_under_6_months                  26707 non-null  category
#  13  health_worker                         26707 non-null  category
#  14  health_insurance                      26707 non-null  category
#  15  opinion_h1n1_vacc_effective           26707 non-null  category
#  16  opinion_h1n1_risk                     26707 non-null  category
#  17  opinion_h1n1_sick_from_vacc           26707 non-null  category
#  18  opinion_seas_vacc_effective           26707 non-null  category
#  19  opinion_seas_risk                     26707 non-null  category
#  20  opinion_seas_sick_from_vacc           26707 non-null  category
#  21  age_group                             26707 non-null  category
#  22  education                             26707 non-null  category
#  23  race                                  26707 non-null  category
#  24  sex                                   26707 non-null  category
#  25  income_poverty                        26707 non-null  category
#  26  marital_status                        26707 non-null  category
#  27  hhs_geo_region                        26707 non-null  category
#  28  census_msa                            26707 non-null  category
#  29  household_adults                      26707 non-null  int8
#  30  household_children                    26707 non-null  int8
#  31  h1n1_vaccine                          26707 non-null  category
#  32  seasonal_vaccine                      26707 non-null  category
#  33  employment_status_Employed            26707 non-null  uint8
#  34  employment_status_Not in Labor Force  26707 non-null  uint8
#  35  employment_status_Unemployed          26707 non-null  uint8
#  36  rent_or_own_Own                       26707 non-null  uint8
#  37  rent_or_own_Rent                      26707 non-null  uint8
# dtypes: category(31), int8(2), uint8(5)
# memory usage: 1.2 MB

# %%
data.isna().sum()
# Out:
# h1n1_concern                            0
# h1n1_knowledge                          0
# behavioral_antiviral_meds               0
# behavioral_avoidance                    0
# behavioral_face_mask                    0
# behavioral_wash_hands                   0
# behavioral_large_gatherings             0
# behavioral_outside_home                 0
# behavioral_touch_face                   0
# doctor_recc_h1n1                        0
# doctor_recc_seasonal                    0
# chronic_med_condition                   0
# child_under_6_months                    0
# health_worker                           0
# health_insurance                        0
# opinion_h1n1_vacc_effective             0
# opinion_h1n1_risk                       0
# opinion_h1n1_sick_from_vacc             0
# opinion_seas_vacc_effective             0
# opinion_seas_risk                       0
# opinion_seas_sick_from_vacc             0
# age_group                               0
# education                               0
# race                                    0
# sex                                     0
# income_poverty                          0
# marital_status                          0
# hhs_geo_region                          0
# census_msa                              0
# household_adults                        0
# household_children                      0
# h1n1_vaccine                            0
# seasonal_vaccine                        0
# employment_status_Employed              0
# employment_status_Not in Labor Force    0
# employment_status_Unemployed            0
# rent_or_own_Own                         0
# rent_or_own_Rent                        0
# dtype: int64

# %%
data['education'].value_counts()
# Out:
# College Graduate    10097
# Some College         7043
# 12 Years             5797
# < 12 Years           2363
# Name: education, dtype: int64
